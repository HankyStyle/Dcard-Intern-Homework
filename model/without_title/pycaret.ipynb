# %% [markdown]
# ## Using PyCaret for Like Prediction with Numerical/Categorical Features

# %%
# !pip install --pre pycaret
# Out:
# Requirement already satisfied: pycaret in /user_data/.local/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.8/dist-packages (from pycaret) (8.7.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (4.62.3)
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.8/dist-packages (from pycaret) (1.23.2)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.5.2)
# Requirement already satisfied: jinja2>=1.2 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: scipy<2.0.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.9.3)
# Requirement already satisfied: joblib>=1.2.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: pyod>=1.0.8 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.0.9)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (2.6.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (3.3.3)
# Requirement already satisfied: numba>=0.55.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.56.4)
# Requirement already satisfied: requests>=2.27.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (2.28.2)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.8/dist-packages (from pycaret) (5.9.4)
# Requirement already satisfied: markupsafe>=2.0.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (6.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pycaret) (5.7.0)
# Requirement already satisfied: cloudpickle in /user_data/.local/lib/python3.8/site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /user_data/.local/lib/python3.8/site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (3.6.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.0.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (5.14.1)
# Requirement already satisfied: kaleido>=0.2.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw>=0.14 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.16)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.8.4rc1)
# Requirement already satisfied: statsmodels>=0.12.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.13.5)
# Requirement already satisfied: sktime>=0.16.1 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (0.17.0)
# Requirement already satisfied: tbats>=1.1.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (1.1.2)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /user_data/.local/lib/python3.8/site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: wurlitzer; platform_system != "Windows" in /user_data/.local/lib/python3.8/site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in /user_data/.local/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /user_data/.local/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /user_data/.local/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.1.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /user_data/.local/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (3.0.24)
# Requirement already satisfied: pygments>=2.4.0 in /user_data/.local/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (2.10.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.8/dist-packages (from ipython>=5.5.0->pycaret) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.5.0->pycaret) (5.6.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.8/dist-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets>=7.6.5->pycaret) (6.17.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /user_data/.local/lib/python3.8/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /user_data/.local/lib/python3.8/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /user_data/.local/lib/python3.8/site-packages (from scikit-learn>=1.0->pycaret) (3.1.0)
# Requirement already satisfied: six in /user_data/.local/lib/python3.8/site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: patsy>=0.5.1 in /user_data/.local/lib/python3.8/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from lightgbm>=3.0.0->pycaret) (0.34.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /user_data/.local/lib/python3.8/site-packages (from numba>=0.55.0->pycaret) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.55.0->pycaret) (65.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /user_data/.local/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /user_data/.local/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /user_data/.local/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /user_data/.local/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (2021.10.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.2.0->pycaret) (5.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /user_data/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /user_data/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /user_data/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /user_data/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /user_data/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /user_data/.local/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (3.0.6)
# Requirement already satisfied: tenacity>=6.2.0 in /user_data/.local/lib/python3.8/site-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Requirement already satisfied: Flask-Cors<4.0.0,>=3.0.10 in /user_data/.local/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.0.10)
# Requirement already satisfied: Werkzeug<=2.1.2 in /user_data/.local/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /user_data/.local/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.9.2)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /user_data/.local/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /user_data/.local/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.8.9)
# Requirement already satisfied: trace-updater>=0.0.8 in /user_data/.local/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: deprecated>=1.2.13 in /user_data/.local/lib/python3.8/site-packages (from sktime>=0.16.1->pycaret) (1.2.13)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /user_data/.local/lib/python3.8/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=5.5.0->pycaret) (2.2.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (5.10.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.19.2)
# Requirement already satisfied: platformdirs>=2.5 in /user_data/.local/lib/python3.8/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.6.2)
# Requirement already satisfied: Flask>=0.9 in /user_data/.local/lib/python3.8/site-packages (from Flask-Cors<4.0.0,>=3.0.10->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /user_data/.local/lib/python3.8/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /user_data/.local/lib/python3.8/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /user_data/.local/lib/python3.8/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in /user_data/.local/lib/python3.8/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: ansi2html in /user_data/.local/lib/python3.8/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.9.0rc1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.8/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: itsdangerous>=2.0 in /user_data/.local/lib/python3.8/site-packages (from Flask>=0.9->Flask-Cors<4.0.0,>=3.0.10->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in /user_data/.local/lib/python3.8/site-packages (from Flask>=0.9->Flask-Cors<4.0.0,>=3.0.10->plotly-resampler>=0.8.3.1->pycaret) (8.0.3)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Read File

# %%
import pandas as pd
import numpy as np
train = pd.read_csv('../../raw_data/intern_homework_train_dataset.csv')
test = pd.read_csv('../../raw_data/intern_homework_public_test_dataset.csv')
train.head()
# Out:
#       title               created_at  like_count_1h  like_count_2h  \
# 0     我的排骨湯  2022-10-05 14:20:21 UTC             12             15
# 1  #請益 婚禮穿搭  2022-10-05 14:28:13 UTC              0              0
# 2    無謂的啦啦隊  2022-10-06 07:18:22 UTC              3              7
# 3   文學理論 課本  2022-09-20 11:39:14 UTC              2              7
# 4      一般課程  2022-09-05 10:18:24 UTC              3              7
#
#    like_count_3h  like_count_4h  like_count_5h  like_count_6h  \
# 0             15             15             16             18
# 1              3              4              4              4
# 2              8             11             12             14
# 3             11             24             26             26
# 4              7             10             10             11
#
#    comment_count_1h  comment_count_2h  comment_count_3h  comment_count_4h  \
# 0                10                10                10                10
# 1                 2                 5                 8                 9
# 2                 1                 1                 2                 3
# 3                 2                 2                 8                32
# 4                15                26                35                38
#
#    comment_count_5h  comment_count_6h  forum_id  author_id  forum_stats  \
# 0                10                10    598518     428921          0.7
# 1                 9                 9    399302     650840         63.9
# 2                 3                 3    650776     717288         19.2
# 3                38                63    471023     173889          7.9
# 4                48                49    230184     594332         36.2
#
#    like_count_24h
# 0              26
# 1              11
# 2              19
# 3              29
# 4              16

# %%
train = train
test = test

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# 挑選 Label

# %%
train_label = train['like_count_24h']
test_label = test['like_count_24h']
train_label
# Out:
# 0        26
# 1        11
# 2        19
# 3        29
# 4        16
#          ..
# 49995    11
# 49996     5
# 49997    13
# 49998    11
# 49999     5
# Name: like_count_24h, Length: 50000, dtype: int64

# %% [markdown]
# 挑選 Input
#
# 不考慮 文章標題 / 作者 ID / 看板 ID

# %%
# 指定要刪除的 column names，並使用 drop 函數將這些 column 刪除
drop_columns = ['author_id', 'forum_id', 'title']

train = train.drop(drop_columns, axis=1)
test = test.drop(drop_columns, axis=1)

# %% [markdown]
# ### Data Transfromations

# %% [markdown]
# 處理 created_by Feature

# %%
# 將文章發佈時間 拆成 星期幾 與 小時 的函數
def split_date(df, date_column):

    # 將 created_by 欄位轉換成日期格式
    df[date_column] = pd.to_datetime(df[date_column], utc=True)
    
    # 新增 星期幾 和 小時 欄位
    df['weekday'] = df[date_column].dt.weekday
    df['hour'] = df[date_column].dt.hour

    # 移除 created_by 欄位
    df = df.drop(date_column, axis=1)

    # 回傳處理過的資料集
    return df

# %%
train = split_date(train, 'created_at')
test = split_date(test, 'created_at')

# 顯示處理過的資料集
train.head()
# Out:
#    like_count_1h  like_count_2h  like_count_3h  like_count_4h  like_count_5h  \
# 0             12             15             15             15             16
# 1              0              0              3              4              4
# 2              3              7              8             11             12
# 3              2              7             11             24             26
# 4              3              7              7             10             10
#
#    like_count_6h  comment_count_1h  comment_count_2h  comment_count_3h  \
# 0             18                10                10                10
# 1              4                 2                 5                 8
# 2             14                 1                 1                 2
# 3             26                 2                 2                 8
# 4             11                15                26                35
#
#    comment_count_4h  comment_count_5h  comment_count_6h  forum_stats  \
# 0                10                10                10          0.7
# 1                 9                 9                 9         63.9
# 2                 3                 3                 3         19.2
# 3                32                38                63          7.9
# 4                38                48                49         36.2
#
#    like_count_24h  weekday  hour
# 0              26        2    14
# 1              11        2    14
# 2              19        3     7
# 3              29        1    11
# 4              16        0    10

# %% [markdown]
# ## Auto Sklearn Training

# %%
from pycaret.regression import *

s = setup(train, target = 'like_count_24h')

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              14:29:36
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library

# %%
print(best)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=6523)

# %%
finalize_model(best)
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['like_count_1h', 'like_count_2h',
#                                              'like_count_3h', 'like_count_4h',
#                                              'like_count_5h', 'like_count_6h',
#                                              'comment_count_1h',
#                                              'comment_count_2h',
#                                              'comment_count_3h',
#                                              'comment_count_4h',
#                                              'comment_count_5h',
#                                              'comment_count_6h', 'forum_stats',
#                                              'weekday', 'hour'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator',
#                  ExtraTreesRegressor(n_jobs=-1, random_state=6523))])

# %%
predict_model(best, test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b92d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b92d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7b92d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7b92d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7b92d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7b92d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7b92d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7b92d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b92d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b92d_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_7b92d_row0_col1" class="data row0 col1" >21.7812</td>
#       <td id="T_7b92d_row0_col2" class="data row0 col2" >12566.0240</td>
#       <td id="T_7b92d_row0_col3" class="data row0 col3" >112.0983</td>
#       <td id="T_7b92d_row0_col4" class="data row0 col4" >0.5518</td>
#       <td id="T_7b92d_row0_col5" class="data row0 col5" >0.6307</td>
#       <td id="T_7b92d_row0_col6" class="data row0 col6" >0.6752</td>
#     </tr>
#   </tbody>
# </table>
#       like_count_1h  like_count_2h  like_count_3h  like_count_4h  \
# 0                 2              7              7             12
# 1                 1              1              1              1
# 2                 2              2              3              3
# 3                 0              0              1              2
# 4                12             21             39             54
# ...             ...            ...            ...            ...
# 9995              5              8              8              8
# 9996              3              6             12             13
# 9997              2              2              2              3
# 9998              0              0              1              1
# 9999              4              5              7              7
#
#       like_count_5h  like_count_6h  comment_count_1h  comment_count_2h  \
# 0                13             14                 0                 1
# 1                 3              4                18                18
# 2                 3              4                 4                 4
# 3                 3              3                 0                 5
# 4                77            107                 6                16
# ...             ...            ...               ...               ...
# 9995              8              8                 1                 1
# 9996             14             15                 5                 7
# 9997              3              3                 2                 2
# 9998              2              2                 0                 0
# 9999              8              9                 1                 2
#
#       comment_count_3h  comment_count_4h  comment_count_5h  comment_count_6h  \
# 0                    1                 1                 2                 2
# 1                   23                26                27                28
# 2                    8                 9                11                11
# 3                    8                14                16                16
# 4                   21                21                23                28
# ...                ...               ...               ...               ...
# 9995                 1                 1                 1                 1
# 9996                 8                11                11                11
# 9997                 3                 3                 3                 3
# 9998                 0                 0                 0                 0
# 9999                 4                 5                 5                 5
#
#       forum_stats  weekday  hour  like_count_24h  prediction_label
# 0       48.599998        5    12              16             26.32
# 1      389.100006        3     0               8             33.92
# 2      389.100006        2     7               8             17.00
# 3       32.700001        4     5               6             11.49
# 4       44.599998        6     4             211            286.42
# ...           ...      ...   ...             ...               ...
# 9995    88.199997        2    15              20             15.43
# 9996    50.599998        0    12              18             30.01
# 9997    72.900002        3    14               6             14.53
# 9998     1.500000        0    10               5              7.71
# 9999     5.400000        3    14              19             26.71
#
# [10000 rows x 17 columns]

# %%
predictions = predict_model(best, test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_20423">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20423_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_20423_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_20423_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_20423_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_20423_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_20423_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_20423_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20423_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20423_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_20423_row0_col1" class="data row0 col1" >21.7812</td>
#       <td id="T_20423_row0_col2" class="data row0 col2" >12566.0240</td>
#       <td id="T_20423_row0_col3" class="data row0 col3" >112.0983</td>
#       <td id="T_20423_row0_col4" class="data row0 col4" >0.5518</td>
#       <td id="T_20423_row0_col5" class="data row0 col5" >0.6307</td>
#       <td id="T_20423_row0_col6" class="data row0 col6" >0.6752</td>
#     </tr>
#   </tbody>
# </table>
